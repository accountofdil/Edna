# %% [markdown]
# <style>
# h1, h1 *,
# h2, h2 *,
# h3, h3 *,
# h4, h4 *,
# h5, h5 *,
# h6, h6 * {
#   font-family: "Times New Roman", Times, serif !important;
#
# </style>
#
# ### **Hotel Booking Cancellations Prediction**

# %% [markdown]
# ---

# %%
import sys
# !{sys.executable} -m pip install streamlit

# %%
import sys
# !{sys.executable} -m pip install joblib

# %%
import pandas as pd
import warnings

warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('Hotel Booking Cancellations Prediction - Dataset.xlsx')

# %%
df
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0                 2               0                     1                  2
# 1                 2               0                     2                  3
# 2                 1               0                     2                  1
# 3                 2               0                     0                  2
# 4                 2               0                     1                  1
# ...             ...             ...                   ...                ...
# 25806             2               2                     0                  1
# 25807             3               0                     2                  6
# 25808             2               0                     1                  3
# 25809             2               0                     2                  6
# 25810             2               0                     0                  3
#
# ...

# %%
df.head()
# Out:
#    no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0             2               0                     1                  2
# 1             2               0                     2                  3
# 2             1               0                     2                  1
# 3             2               0                     0                  2
# 4             2               0                     1                  1
#
#   type_of_meal_plan  required_car_parking_space  lead_time  arrival_year  \
# 0       Meal Plan 1                           0        224          2017
# 1      Not Selected                           0          5          2018
# 2       Meal Plan 1                           0          1          2018
# 3       Meal Plan 1                           0        211          2018
# 4      Not Selected                           0         48          2018
#
#    arrival_month  arrival_date  repeated_guest  no_of_previous_cancellations  \
# ...

# %%
df.dtypes
# Out:
# no_of_adults                              int64
# no_of_children                            int64
# no_of_weekend_nights                      int64
# no_of_week_nights                         int64
# type_of_meal_plan                        object
# required_car_parking_space                int64
# lead_time                                 int64
# arrival_year                              int64
# arrival_month                             int64
# arrival_date                              int64
# repeated_guest                            int64
# no_of_previous_cancellations              int64
# no_of_previous_bookings_not_canceled      int64
# avg_price_per_room                      float64
# no_of_special_requests                    int64
# booking_status                           object
# dtype: object

# %%
df.shape
# Out:
# (25811, 16)

# %%
df.describe()
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# count  25811.000000    25811.000000          25811.000000       25811.000000
# mean       1.890744        0.142265              0.883034           2.263918
# std        0.529264        0.464034              0.887990           1.514417
# min        0.000000        0.000000              0.000000           0.000000
# 25%        2.000000        0.000000              0.000000           1.000000
# 50%        2.000000        0.000000              1.000000           2.000000
# 75%        2.000000        0.000000              2.000000           3.000000
# max        4.000000       10.000000              7.000000          17.000000
#
#        required_car_parking_space     lead_time  arrival_year  arrival_month  \
# count                25811.000000  25811.000000  25811.000000   25811.000000
# mean                     0.042424     65.548836   2017.850490       7.331099
# ...

# %%
df.describe(include = 'object')
# Out:
#        type_of_meal_plan booking_status
# count              25811          25811
# unique                 4              2
# top          Meal Plan 1   Not_Canceled
# freq               20265          18542

# %%
df['booking_status'].value_counts()
# Out:
# booking_status
# Not_Canceled    18542
# Canceled         7269
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0             2               0                     1                  2
# 1             2               0                     2                  3
# 2             1               0                     2                  1
# 3             2               0                     0                  2
# 4             2               0                     1                  1
#
#   type_of_meal_plan  required_car_parking_space  lead_time  arrival_year  \
# 0       Meal Plan 1                           0        224          2017
# 1      Not Selected                           0          5          2018
# 2       Meal Plan 1                           0          1          2018
# 3       Meal Plan 1                           0        211          2018
# 4      Not Selected                           0         48          2018
#
#    arrival_month  arrival_date  repeated_guest  no_of_previous_cancellations  \
# ...

# %%
df['total_guests'] = df['no_of_adults'] + df['no_of_children']

# %%
df.head()
# Out:
#    no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0             2               0                     1                  2
# 1             2               0                     2                  3
# 2             1               0                     2                  1
# 3             2               0                     0                  2
# 4             2               0                     1                  1
#
#   type_of_meal_plan  required_car_parking_space  lead_time  arrival_year  \
# 0       Meal Plan 1                           0        224          2017
# 1      Not Selected                           0          5          2018
# 2       Meal Plan 1                           0          1          2018
# 3       Meal Plan 1                           0        211          2018
# 4      Not Selected                           0         48          2018
#
#    arrival_month  arrival_date  repeated_guest  no_of_previous_cancellations  \
# ...

# %%
df['total_nights'] = df['no_of_weekend_nights'] + df['no_of_week_nights']

# %%
df.head()
# Out:
#    no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0             2               0                     1                  2
# 1             2               0                     2                  3
# 2             1               0                     2                  1
# 3             2               0                     0                  2
# 4             2               0                     1                  1
#
#   type_of_meal_plan  required_car_parking_space  lead_time  arrival_year  \
# 0       Meal Plan 1                           0        224          2017
# 1      Not Selected                           0          5          2018
# 2       Meal Plan 1                           0          1          2018
# 3       Meal Plan 1                           0        211          2018
# 4      Not Selected                           0         48          2018
#
#    arrival_month  arrival_date  repeated_guest  no_of_previous_cancellations  \
# ...

# %%
df['booking_status'].value_counts(normalize = True)
# Out:
# booking_status
# Not_Canceled    0.718376
# Canceled        0.281624
# Name: proportion, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rcParams

# %%
rcParams['font.family'] = 'Times New Roman'

fig, ax = plt.subplots(figsize = (10, 6))
sns.countplot(data = df, x = 'booking_status', ax = ax, color = 'black')
ax.set_title('Booking Status Distribution', fontweight = 'bold', fontsize = 12)
ax.set_xlabel('Booking Status', fontweight = 'bold')
ax.set_ylabel('Count', fontweight = 'bold')
ax.grid(True, linestyle = '--', alpha = 0.3)

plt.show()

# %%
num_cols = df.select_dtypes(include = ['int64', 'float64']).columns

# %%
num_cols
# Out:
# Index(['no_of_adults', 'no_of_children', 'no_of_weekend_nights',
#        'no_of_week_nights', 'required_car_parking_space', 'lead_time',
#        'arrival_year', 'arrival_month', 'arrival_date', 'repeated_guest',
#        'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled',
#        'avg_price_per_room', 'no_of_special_requests', 'total_guests',
#        'total_nights'],
#       dtype='object')

# %%
df[num_cols].hist(figsize = (15, 10), bins = 20, color = 'black', edgecolor = 'white')
plt.tight_layout()
plt.show()

# %%
for col in num_cols:
    fig, ax = plt.subplots(figsize = (10, 6))
    sns.boxplot(x = df[col], ax = ax, color = 'grey')
    ax.set_title(col, fontweight = 'bold', fontsize = 12)
    ax.set_xlabel(col, fontweight = 'bold')
    ax.grid(True, linestyle = '--', alpha = 0.3)
    plt.show()

# %%
df.groupby('booking_status')['lead_time'].mean()
# Out:
# booking_status
# Canceled        104.366488
# Not_Canceled     50.331194
# Name: lead_time, dtype: float64

# %%
df.groupby('booking_status')['avg_price_per_room'].mean()
# Out:
# booking_status
# Canceled        115.347719
# Not_Canceled    101.984183
# Name: avg_price_per_room, dtype: float64

# %%
df.groupby('booking_status')['total_guests'].mean()
# Out:
# booking_status
# Canceled        2.163434
# Not_Canceled    1.981879
# Name: total_guests, dtype: float64

# %%
df.groupby(['type_of_meal_plan', 'booking_status']).size().unstack()
# Out:
# booking_status     Canceled  Not_Canceled
# type_of_meal_plan
# Meal Plan 1            5500         14765
# Meal Plan 2             368           710
# Meal Plan 3               1             4
# Not Selected           1400          3063

# %%
pivot_price = pd.pivot_table(df,
                             values = 'avg_price_per_room',
                             index = 'arrival_month',
                             columns = 'booking_status',
                             aggfunc = 'mean')
pivot_price
# Out:
# booking_status    Canceled  Not_Canceled
# arrival_month
# 1                80.712500     74.699604
# 2                85.791088     81.922206
# 3               102.712011     88.245341
# 4               114.445248    101.441568
# 5               127.641138    114.316431
# 6               121.214241    110.758705
# 7               116.580144    113.607542
# 8               120.482596    113.883753
# 9               128.644103    116.043386
# 10              118.100183    105.619292
# 11               97.427061     90.155855
# 12               97.057382     91.543426

# %%
pivot_no_of_adults = pd.pivot_table(df,
                                    values = 'no_of_adults',
                                    index = 'arrival_month',
                                    columns = 'booking_status',
                                    aggfunc = 'mean')
pivot_no_of_adults
# Out:
# booking_status  Canceled  Not_Canceled
# arrival_month
# 1               1.875000      1.676781
# 2               1.764912      1.798834
# 3               1.959410      1.863510
# 4               1.915200      1.911238
# 5               1.912434      1.852498
# 6               1.996510      1.857714
# 7               2.046512      2.051787
# 8               2.097663      1.982646
# 9               1.947245      1.804428
# 10              1.966781      1.789773
# 11              1.804082      1.761792
# 12              1.997059      1.899168

# %%
cancel_rate = df.groupby('arrival_month')['booking_status'].apply(lambda x: (x == 'Canceled').mean())
cancel_rate
# Out:
# arrival_month
# 1     0.020672
# 2     0.216895
# 3     0.274014
# 4     0.309100
# 5     0.311681
# 6     0.314145
# 7     0.397098
# 8     0.393820
# 9     0.282357
# 10    0.276178
# 11    0.224154
# 12    0.142677
# Name: booking_status, dtype: float64

# %%
fig, ax = plt.subplots(figsize = (10, 6))
cancel_rate.plot(kind = 'bar', ax = ax, color = 'black', linewidth = 1.5)
ax.set_title('Cancellation Rate by Month', fontweight = 'bold', fontsize = 12)
ax.set_xlabel('Month', fontweight = 'bold')
ax.set_ylabel('Cancellation Rate', fontweight = 'bold')
ax.grid(True, linestyle = '--', alpha = 0.3)

plt.show()

# %%
fig, ax = plt.subplots(figsize = (10, 6))
sns.boxplot(data = df, x = 'booking_status', y = 'lead_time', ax = ax, color = 'grey')
ax.set_title('Lead Time v. Cancellation', fontweight = 'bold', fontsize = 12)
ax.set_xlabel('Booking Status', fontweight = 'bold')
ax.set_ylabel('Lead Time', fontweight = 'bold')
ax.grid(True, linestyle = '--', alpha = 0.3)

plt.show()

# %%
fig, ax = plt.subplots(figsize = (10, 6))
sns.countplot(data = df,
              x = 'arrival_month',
              hue = 'booking_status',
              palette = ['black', 'grey'],
              ax = ax)
ax.set_title('Monthly Booking Trend', fontweight = 'bold', fontsize = 12)
ax.set_xlabel('Arrival Month', fontweight = 'bold')
ax.set_ylabel('Count', fontweight = 'bold')
ax.grid(True, linestyle = '--', alpha = 0.3)
ax.tick_params(axis = 'x', rotation = 45)

plt.show()

# %%
df.head()
# Out:
#    no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0             2               0                     1                  2
# 1             2               0                     2                  3
# 2             1               0                     2                  1
# 3             2               0                     0                  2
# 4             2               0                     1                  1
#
#   type_of_meal_plan  required_car_parking_space  lead_time  arrival_year  \
# 0       Meal Plan 1                           0        224          2017
# 1      Not Selected                           0          5          2018
# 2       Meal Plan 1                           0          1          2018
# 3       Meal Plan 1                           0        211          2018
# 4      Not Selected                           0         48          2018
#
#    arrival_month  arrival_date  repeated_guest  no_of_previous_cancellations  \
# ...

# %%
df['booking_status'] = df['booking_status'].replace({'Not_Canceled': 1,
                                                     'Canceled': 0})
df.head()
# Out:
#    no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0             2               0                     1                  2
# 1             2               0                     2                  3
# 2             1               0                     2                  1
# 3             2               0                     0                  2
# 4             2               0                     1                  1
#
#   type_of_meal_plan  required_car_parking_space  lead_time  arrival_year  \
# 0       Meal Plan 1                           0        224          2017
# 1      Not Selected                           0          5          2018
# 2       Meal Plan 1                           0          1          2018
# 3       Meal Plan 1                           0        211          2018
# 4      Not Selected                           0         48          2018
#
#    arrival_month  arrival_date  repeated_guest  no_of_previous_cancellations  \
# ...

# %%
df['is_weekend_heavy'] = (df['no_of_weekend_nights'] > df['no_of_week_nights']).astype(int)
df.head()
# Out:
#    no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0             2               0                     1                  2
# 1             2               0                     2                  3
# 2             1               0                     2                  1
# 3             2               0                     0                  2
# 4             2               0                     1                  1
#
#   type_of_meal_plan  required_car_parking_space  lead_time  arrival_year  \
# 0       Meal Plan 1                           0        224          2017
# 1      Not Selected                           0          5          2018
# 2       Meal Plan 1                           0          1          2018
# 3       Meal Plan 1                           0        211          2018
# 4      Not Selected                           0         48          2018
#
#    arrival_month  arrival_date  repeated_guest  no_of_previous_cancellations  \
# ...

# %%
df.columns
# Out:
# Index(['no_of_adults', 'no_of_children', 'no_of_weekend_nights',
#        'no_of_week_nights', 'type_of_meal_plan', 'required_car_parking_space',
#        'lead_time', 'arrival_year', 'arrival_month', 'arrival_date',
#        'repeated_guest', 'no_of_previous_cancellations',
#        'no_of_previous_bookings_not_canceled', 'avg_price_per_room',
#        'no_of_special_requests', 'booking_status', 'total_guests',
#        'total_nights', 'is_weekend_heavy'],
#       dtype='object')

# %%
features = ['lead_time',
            'avg_price_per_room',
            'no_of_special_requests',
            'total_guests',
            'total_nights',
            'repeated_guest']

X = df[features]
y = df['booking_status']

# %%
X
# Out:
#        lead_time  avg_price_per_room  no_of_special_requests  total_guests  \
# 0            224               65.00                       0             2
# 1              5              106.68                       1             2
# 2              1               60.00                       0             1
# 3            211              100.00                       0             2
# 4             48               94.50                       0             2
# ...          ...                 ...                     ...           ...
# 25806          0              216.00                       0             4
# 25807         85              167.80                       1             3
# 25808        228               90.95                       2             2
# 25809        148               98.39                       2             2
# 25810         63               94.50                       0             2
#
#        total_nights  repeated_guest
# ...

# %%
y
# Out:
# 0        1
# 1        1
# 2        0
# 3        0
# 4        0
#         ..
# 25806    0
# 25807    1
# 25808    0
# 25809    1
# 25810    0
# Name: booking_status, Length: 25811, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, stratify = y)

# %%
y.value_counts()
# Out:
# booking_status
# 1    18542
# 0     7269
# Name: count, dtype: int64

# %%
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

classes = np.unique(y_train)
classes
# Out:
# array([0, 1])

# %%
weights = compute_class_weight(class_weight = 'balanced', classes = classes, y = y_train)
weights
# Out:
# array([1.77540843, 0.69601564])

# %%
class_weights = dict(zip(classes, weights))
class_weights
# Out:
# {np.int64(0): np.float64(1.775408426483233),
#  np.int64(1): np.float64(0.6960156408009168)}

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV

# %%
rf = RandomForestClassifier(class_weight = class_weights)

# %%
rf_params = {'n_estimators': [100, 200, 300], 
             'max_depth': [5, 10, 20, None],
             'min_samples_split': [2, 5, 10],
             'min_samples_leaf': [1, 2, 4]}

# %%
rf_random = RandomizedSearchCV(rf, 
                               rf_params, 
                               n_iter = 20, 
                               cv = 3, 
                               scoring = 'accuracy', 
                               n_jobs = -1)

# %%
rf_random.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=3,
#                    estimator=RandomForestClassifier(class_weight={np.int64(0): np.float64(1.775408426483233),
#                                                                   np.int64(1): np.float64(0.6960156408009168)}),
#                    n_iter=20, n_jobs=-1,
#                    param_distributions={'max_depth': [5, 10, 20, None],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [100, 200, 300]},
#                    scoring='accuracy')

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 300,
#  'min_samples_split': 2,
#  'min_samples_leaf': 2,
#  'max_depth': 20}

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gb = GradientBoostingClassifier()

# %%
gb_params = {'n_estimators': [100, 200],
             'learning_rate': [0.01, 0.1, 0.2],
             'max_depth': [3, 5, 7]}

# %%
gb_random = RandomizedSearchCV(gb,
                               gb_params,
                               n_iter = 15, 
                               cv = 3,
                               scoring = 'accuracy',
                               n_jobs = -1)

# %%
gb_random.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=3, estimator=GradientBoostingClassifier(), n_iter=15,
#                    n_jobs=-1,
#                    param_distributions={'learning_rate': [0.01, 0.1, 0.2],
#                                         'max_depth': [3, 5, 7],
#                                         'n_estimators': [100, 200]},
#                    scoring='accuracy')

# %%
gb_random.best_params_
# Out:
# {'n_estimators': 200, 'max_depth': 3, 'learning_rate': 0.1}

# %%
from xgboost import XGBClassifier

# %%
xgb = XGBClassifier(scale_pos_weight = class_weights[0] / class_weights[1],
                    eval_metric = 'logloss')

# %%
xgb_params = {'n_estimators': [100, 200, 300],
              'max_depth': [3, 5, 7],
              'learning_rate': [0.01, 0.1, 0.2],
              'subsample': [0.7, 1.0],
              'colsample_bytree': [0.7, 1.0]}

# %%
xgb_random = RandomizedSearchCV(xgb,
                                xgb_params,
                                n_iter = 20,
                                cv = 3,
                                scoring = 'accuracy',
                                n_jobs = -1)

# %%
xgb_random.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=3,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, device=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=True,
#                                            eval_metric='logloss',
#                                            feature_types=None,
#                                            feature_weights=None, gamma=None,
#                                            grow_policy=None,
#                                            importance_type=None,
#                                            interaction_const...
# ...

# %%
xgb_random.best_params_
# Out:
# {'subsample': 1.0,
#  'n_estimators': 300,
#  'max_depth': 7,
#  'learning_rate': 0.2,
#  'colsample_bytree': 1.0}

# %%
from sklearn.metrics import accuracy_score

# %%
models = {'Random Forest': rf_random.best_estimator_,
          'Gradient Boosting': gb_random.best_estimator_,
          'XGBoost': xgb_random.best_estimator_}

# %%
for name, model in models.items():
    print(f"{name}")
    y_pred = model.predict(X_test)
    print(accuracy_score(y_test, y_pred))
# Out:
# Random Forest
# 0.8140615920976176
# Gradient Boosting
# 0.8241332558589967
# XGBoost
# 0.8159984505132675

# %%
import joblib

best_model = gb_random.best_estimator_
joblib.dump(best_model, 'Hotel Booking Cancellations Prediction - Gradient Boosting Model.pkl')
# Out:
# ['Hotel Booking Cancellations Prediction - Gradient Boosting Model.pkl']

# %%
features
# Out:
# ['lead_time',
#  'avg_price_per_room',
#  'no_of_special_requests',
#  'total_guests',
#  'total_nights',
#  'repeated_guest']

# %%
import sys
import sklearn

print(sys.executable)
print(sklearn.__version__)
# Out:
# C:\Users\dilan\AppData\Local\Programs\Python\Python312\python.exe
# 1.5.2
